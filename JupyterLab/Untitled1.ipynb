# %%
import numpy as np
import matplotlib.pytlotlib.pyplot as plt
## Visualización en spider
a1=np.aarray([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pytlotlib.pyplot as plt
#       3 ## Visualización en spider
#       4 a1=np.aarray([1,2,3])
#
# ModuleNotFoundError: No module named 'matplotlib.pytlotlib'
